# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\philipp\anaconda3\lib\site-packages
# Requirement already satisfied: wheel>=0.26 in c:\users\philipp\anaconda3\lib\site-packages (from tensorflow)
# Requirement already satisfied: protobuf>=3.3.0 in c:\users\philipp\anaconda3\lib\site-packages (from tensorflow)
# Requirement already satisfied: numpy>=1.12.1 in c:\users\philipp\anaconda3\lib\site-packages (from tensorflow)
# Requirement already satisfied: tensorflow-tensorboard<0.5.0,>=0.4.0rc1 in c:\users\philipp\anaconda3\lib\site-packages (from tensorflow)
# Requirement already satisfied: six>=1.10.0 in c:\users\philipp\anaconda3\lib\site-packages (from tensorflow)
# Requirement already satisfied: enum34>=1.1.6 in c:\users\philipp\anaconda3\lib\site-packages (from tensorflow)
# Requirement already satisfied: setuptools in c:\users\philipp\anaconda3\lib\site-packages (from protobuf>=3.3.0->tensorflow)
# Requirement already satisfied: html5lib==0.9999999 in c:\users\philipp\anaconda3\lib\site-packages (from tensorflow-tensorboard<0.5.0,>=0.4.0rc1->tensorflow)
# Requirement already satisfied: werkzeug>=0.11.10 in c:\users\philipp\anaconda3\lib\site-packages (from tensorflow-tensorboard<0.5.0,>=0.4.0rc1->tensorflow)
# Requirement already satisfied: bleach==1.5.0 in c:\users\philipp\anaconda3\lib\site-packages (from tensorflow-tensorboard<0.5.0,>=0.4.0rc1->tensorflow)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\philipp\anaconda3\lib\site-packages (from tensorflow-tensorboard<0.5.0,>=0.4.0rc1->tensorflow)

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename


filename = maybe_download('text8.zip', 31344016)


# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0

# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer[:] = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])

# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)


graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()

# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
# Out:
# C:\Users\Philipp\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 6 a
# 195 term -> 2 of
# Initialized
# Average loss at step  0 :  287.16229248046875
# Nearest to into: lamarckian, drowsiness, purposes, resettled, illness, prudence, allusion, rockers,
# Nearest to known: offa, functions, slam, midland, branson, endanger, weiner, appended,
# Nearest to but: orford, prophet, euler, ssris, mapmaking, copylefted, giuliani, subfields,
# Nearest to not: runs, wang, earmarked, cahiers, imitated, papacy, swordsmiths, salim,
# Nearest to than: tasting, navigate, kumquats, cursus, massless, living, giotto, banks,
# Nearest to so: skopje, gd, magellanic, bissau, materiality, debrecen, meridian, regrets,
# Nearest to nine: concerted, harappan, northrop, shula, propelling, bourgeoisie, communication, romanization,
# Nearest to if: fuzzy, warren, inauguration, curled, municipal, catechism, algiers, mchale,
# Nearest to american: dominate, garvey, hope, servo, later, outbreak, solitaire, harman,
# Nearest to such: barring, consisting, stellar, sleeping, unbiased, meager, despair, affiliate,
# Nearest to years: laterally, cisc, suggested, insistence, periodicity, piro, brundtland, burr,
# Nearest to four: endless, locksmiths, toolkits, reinstatement, optimally, pharmaceuticals, plum, birmingham,
# Nearest to which: denial, pathologies, bid, charm, devoted, acre, venn, motors,
# Nearest to five: boolean, indies, archibald, guppy, mcdaniel, quicktime, factory, gunn,
# Nearest to many: urals, multiply, mercenaries, mattress, airports, esa, bluescreen, middleton,
# Nearest to has: bram, macrolides, lunch, sourcebook, farmland, anointing, erebus, fulfillment,
# Average loss at step  2000 :  114.47816834831238
# Average loss at step  4000 :  52.11986704134941
# Average loss at step  6000 :  33.19201273441315
# Average loss at step  8000 :  23.64167074418068
# Average loss at step  10000 :  17.59603215241432
# Nearest to into: purposes, piano, figure, illness, five, americas, soviet, in,
# Nearest to known: functions, slam, ranged, ltd, bckgr, awarded, velocity, frames,
# Nearest to but: prophet, agave, aberdeenshire, dispelling, collins, architect, bckgr, in,
# Nearest to not: runs, atomism, tragic, and, rothbard, imitated, airports, wang,
# Nearest to than: banks, living, tasting, term, and, kg, coke, no,
# Nearest to so: phi, existence, e, bissau, and, willard, vinegar, ho,
# Nearest to nine: eight, zero, agave, one, phi, bckgr, coke, basins,
# Nearest to if: municipal, incorporated, union, warren, fuzzy, inauguration, algiers, october,
# Nearest to american: telling, later, ez, dominate, hope, hearing, behavioral, stanford,
# Nearest to such: consisting, supporters, ambushed, india, plants, despair, a, church,
# Nearest to years: laterally, reason, suggested, almonds, collections, contrary, basins, insistence,
# Nearest to four: nine, one, coke, bckgr, zero, vs, victoriae, module,
# Nearest to which: denial, season, tissue, devoted, acre, chi, spaceflight, bckgr,
# Nearest to five: zero, nine, six, bckgr, boolean, one, coke, receiving,
# Nearest to many: mercenaries, execution, lord, coordinated, lymphoma, esa, camus, defensive,
# Nearest to has: was, is, have, messenger, museum, sigma, studios, kangaroo,
# Average loss at step  12000 :  14.286112918496132
# Average loss at step  14000 :  11.797161420226097
# Average loss at step  16000 :  9.986318214893341
# Average loss at step  18000 :  8.473075753331184
# Average loss at step  20000 :  8.130895179748535
# Nearest to into: and, in, piano, americas, five, purposes, soviet, on,
# Nearest to known: midland, functions, ranged, slam, ltd, antwerp, accidentally, defeated,
# Nearest to but: and, prophet, agave, peptide, pompidou, agni, bckgr, nuremberg,
# Nearest to not: tragic, atomism, runs, to, dasyprocta, airports, nicephorus, sometimes,
# Nearest to than: dasyprocta, banks, tasting, living, circ, term, and, kg,
# Nearest to so: phi, listening, meridian, epistles, willard, bissau, UNK, magellanic,
# Nearest to nine: eight, six, zero, seven, five, four, three, circ,
# Nearest to if: municipal, warren, union, inauguration, incorporated, hakama, fuzzy, antwerp,
# Nearest to american: and, circ, telling, hearing, ile, ez, garvey, hope,
# Nearest to such: these, consisting, ambushed, supporters, india, despair, conservatism, church,
# Nearest to years: laterally, reason, almonds, contrary, troubles, suggested, basins, collections,
# Nearest to four: nine, zero, eight, seven, six, five, circ, three,
# Nearest to which: and, that, it, UNK, matrices, also, apatosaurus, this,
# Nearest to five: nine, zero, eight, six, seven, four, three, two,
# Nearest to many: circ, the, apatosaurus, dasyprocta, esa, some, hunted, execution,
# Nearest to has: was, is, have, had, messenger, by, would, as,
# Average loss at step  22000 :  6.79717433476448
# Average loss at step  24000 :  6.850709305882454
# Average loss at step  26000 :  6.739203668355942
# Average loss at step  28000 :  6.366854174256325
# Average loss at step  30000 :  5.967515427947045
# Nearest to into: and, in, on, purposes, by, piano, soviet, americas,
# Nearest to known: midland, ranged, functions, branson, slam, ltd, well, accidentally,
# Nearest to but: and, agave, bckgr, peptide, dasyprocta, prophet, agni, circ,
# Nearest to not: to, they, tragic, lauderdale, also, airports, sometimes, dasyprocta,
# Nearest to than: and, banks, dasyprocta, cmf, term, diet, tasting, herschel,
# Nearest to so: listening, meridian, phi, amalthea, epistles, gd, bissau, magellanic,
# Nearest to nine: eight, seven, six, five, four, zero, three, circ,
# Nearest to if: municipal, louisville, warren, otimes, union, hakama, antwerp, inauguration,
# Nearest to american: and, circ, hearing, telling, ile, tubing, sedgwick, garvey,
# Nearest to such: these, consisting, conservatism, ambushed, supporters, telangana, circ, despair,
# Nearest to years: laterally, almonds, reason, contrary, two, invoke, troubles, polytheism,
# Nearest to four: six, five, eight, seven, three, nine, zero, two,
# Nearest to which: that, this, it, also, and, apatosaurus, matrices, one,
# Nearest to five: four, eight, six, seven, zero, nine, three, two,
# Nearest to many: some, circ, the, amalthea, hunted, rutgers, cy, esa,
# Nearest to has: is, was, had, have, messenger, by, determining, sigma,
# Average loss at step  32000 :  5.949199246168137
# Average loss at step  34000 :  5.668942466259002
# Average loss at step  36000 :  5.7096757200956345
# Average loss at step  38000 :  5.5335541410446165
# Average loss at step  40000 :  5.265134719848633
# Nearest to into: from, on, and, in, under, soviet, perfume, americas,
# Nearest to known: midland, branson, stitch, ranged, well, functions, slam, ltd,
# Nearest to but: and, however, agave, bckgr, which, agni, that, zero,
# Nearest to not: to, they, zero, tragic, lauderdale, now, sometimes, also,
# Nearest to than: or, banks, cmf, dasyprocta, diet, and, tasting, term,
# Nearest to so: listening, meridian, gd, amalthea, epistles, abet, phi, magellanic,
# Nearest to nine: eight, seven, zero, six, five, four, three, circ,
# Nearest to if: municipal, recitative, louisville, when, warren, zero, though, will,
# Nearest to american: circ, hearing, telling, british, motorized, tubing, littoral, sedgwick,
# Nearest to such: these, conservatism, well, ambushed, consisting, supporters, telangana, circ,
# Nearest to years: laterally, almonds, reason, invoke, polytheism, two, contrary, cisc,
# Nearest to four: five, six, eight, seven, three, zero, two, nine,
# Nearest to which: that, this, it, also, and, one, zero, apatosaurus,
# Nearest to five: four, eight, seven, three, six, zero, nine, two,
# Nearest to many: some, circ, these, amalthea, the, cy, its, rutgers,
# Nearest to has: had, is, was, have, messenger, determining, by, are,
# Average loss at step  42000 :  5.436158985972405
# Average loss at step  44000 :  5.249668120861053
# Average loss at step  46000 :  5.262291645288467
# Average loss at step  48000 :  5.225640260219574
# Average loss at step  50000 :  4.987363951683045
# Nearest to into: and, in, from, on, under, purposes, five, arjuna,
# Nearest to known: midland, branson, well, stitch, ranged, offa, functions, kapoor,
# Nearest to but: and, however, bckgr, kapoor, agave, agni, circ, or,
# Nearest to not: they, to, it, now, lauderdale, also, tragic, sometimes,
# Nearest to than: or, and, banks, dasyprocta, cmf, diet, much, tasting,
# Nearest to so: listening, gd, amalthea, fruity, meridian, are, magellanic, abet,
# Nearest to nine: eight, seven, six, five, zero, three, four, kapoor,
# Nearest to if: when, recitative, municipal, louisville, will, though, is, for,
# Nearest to american: british, circ, hearing, utraquists, tubing, motorized, telling, frau,
# Nearest to such: these, well, conservatism, ambushed, consisting, supporters, telangana, circ,
# Nearest to years: laterally, almonds, invoke, reason, polytheism, troubles, contrary, cisc,
# Nearest to four: five, six, three, eight, seven, two, circ, one,
# Nearest to which: that, this, it, also, one, and, still, but,
# Nearest to five: four, three, six, eight, seven, zero, two, kapoor,
# Nearest to many: some, these, circ, several, amalthea, cy, rutgers, hunted,
# Nearest to has: had, was, is, have, messenger, determining, by, drain,
# Average loss at step  52000 :  5.04421092748642
# Average loss at step  54000 :  5.181501727938652
# Average loss at step  56000 :  5.037363636136055
# Average loss at step  58000 :  5.065362357497215
# Average loss at step  60000 :  4.942455628156662
# Nearest to into: from, through, on, in, under, spotter, piano, michelob,
# Nearest to known: well, midland, branson, stitch, ranged, offa, kapoor, kolmogorov,
# Nearest to but: however, and, bckgr, circ, kapoor, or, dasyprocta, agave,
# Nearest to not: they, to, it, now, lauderdale, sometimes, you, generally,
# Nearest to than: or, banks, cmf, dasyprocta, much, diet, ursus, tasting,
# Nearest to so: listening, amalthea, microsite, fruity, hence, meridian, gd, abet,
# Nearest to nine: eight, six, seven, four, five, zero, three, michelob,
# Nearest to if: when, is, recitative, though, microsite, will, louisville, but,
# Nearest to american: british, circ, hearing, utraquists, telling, tubing, frau, motorized,
# Nearest to such: these, well, conservatism, many, telangana, ambushed, chemical, consisting,
# Nearest to years: laterally, almonds, ursus, polytheism, reason, invoke, six, troubles,
# Nearest to four: five, six, eight, three, seven, nine, two, circ,
# Nearest to which: that, this, also, it, one, but, operatorname, still,
# Nearest to five: four, six, eight, three, seven, nine, two, zero,
# Nearest to many: some, these, several, circ, ursus, amalthea, rutgers, the,
# Nearest to has: had, have, was, is, messenger, determining, drain, sigma,
# Average loss at step  62000 :  4.9920687512159345
# Average loss at step  64000 :  4.831877579212189
# Average loss at step  66000 :  4.593570374250412
# Average loss at step  68000 :  4.980256448864937
# Average loss at step  70000 :  4.904524906516075
# Nearest to into: from, through, on, and, under, arjuna, spotter, michelob,
# Nearest to known: well, midland, branson, stitch, ranged, offa, kapoor, kolmogorov,
# Nearest to but: however, and, cebus, or, bckgr, while, which, circ,
# Nearest to not: they, to, now, it, also, you, generally, lauderdale,
# Nearest to than: or, and, banks, dasyprocta, cmf, but, much, ursus,
# Nearest to so: listening, entrenched, amalthea, microsite, fruity, cebus, meridian, epistles,
# Nearest to nine: eight, seven, six, five, four, zero, three, michelob,
# Nearest to if: when, cebus, though, but, recitative, louisville, is, microsite,
# Nearest to american: british, hearing, utraquists, circ, telling, tubing, frau, motorized,
# Nearest to such: these, well, conservatism, many, consisting, telangana, despair, chemical,
# Nearest to years: laterally, ursus, almonds, five, polytheism, reason, four, invoke,
# Nearest to four: six, five, three, eight, seven, two, nine, zero,
# Nearest to which: that, this, it, also, but, one, thaler, and,
# Nearest to five: four, six, three, eight, seven, nine, two, zero,
# Nearest to many: some, several, these, circ, other, ursus, its, amalthea,
# Nearest to has: had, have, was, is, determining, messenger, nsc, sigma,
# Average loss at step  72000 :  4.74994022500515
# Average loss at step  74000 :  4.8021734871864314
# Average loss at step  76000 :  4.729362220168114
# Average loss at step  78000 :  4.793839568376542
# Average loss at step  80000 :  4.791892159938812
# Nearest to into: from, through, in, on, under, spotter, and, pontificia,
# Nearest to known: well, midland, branson, stitch, popeye, ranged, such, offa,
# Nearest to but: however, and, cebus, although, while, bckgr, circ, dasyprocta,
# Nearest to not: they, now, to, it, often, sometimes, you, microcebus,
# Nearest to than: or, but, and, banks, cmf, dasyprocta, much, ursus,
# Nearest to so: listening, hence, entrenched, amalthea, cebus, fruity, ghanaian, microsite,
# Nearest to nine: eight, six, seven, five, zero, four, three, kapoor,
# Nearest to if: when, cebus, though, recitative, but, pandemics, microsite, acp,
# Nearest to american: british, circ, utraquists, hearing, telling, tubing, frau, motorized,
# Nearest to such: these, well, many, conservatism, known, consisting, telangana, attackers,
# Nearest to years: laterally, ursus, polytheism, five, almonds, invoke, six, carrera,
# Nearest to four: six, five, three, seven, eight, two, zero, nine,
# Nearest to which: that, this, it, also, but, thaler, one, operatorname,
# Nearest to five: six, four, seven, eight, three, zero, nine, two,
# Nearest to many: some, several, these, circ, other, all, ursus, amalthea,
# Nearest to has: had, have, was, is, determining, messenger, sigma, having,
# Average loss at step  82000 :  4.756342822313309
# Average loss at step  84000 :  4.76237339246273
# Average loss at step  86000 :  4.776035783529282
# Average loss at step  88000 :  4.748338738799095
# Average loss at step  90000 :  4.731515421152115
# Nearest to into: through, from, on, spotter, under, with, drowsiness, pontificia,
# Nearest to known: well, midland, branson, stitch, such, ranged, popeye, used,
# Nearest to but: however, and, while, cebus, bckgr, although, circ, or,
# Nearest to not: they, now, often, to, it, microcebus, you, generally,
# Nearest to than: or, but, much, cmf, banks, and, dasyprocta, ursus,
# Nearest to so: hence, chymotrypsin, amalthea, tombaugh, cebus, fruity, gd, listening,
# Nearest to nine: eight, seven, six, five, four, zero, three, kapoor,
# Nearest to if: when, cebus, though, but, where, recitative, microsite, since,
# Nearest to american: british, telling, utraquists, motorized, circ, tubing, frau, hearing,
# Nearest to such: these, well, many, conservatism, known, attackers, consisting, telangana,
# Nearest to years: five, laterally, ursus, polytheism, almonds, carrera, invoke, pheasants,
# Nearest to four: five, six, seven, three, eight, two, nine, kapoor,
# Nearest to which: that, this, it, also, but, and, both, thaler,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to many: some, several, these, circ, other, all, aquilegia, ursus,
# Nearest to has: had, have, is, was, messenger, determining, having, nsc,
# Average loss at step  92000 :  4.67162294113636
# Average loss at step  94000 :  4.731317801237107
# Average loss at step  96000 :  4.699640934348106
# Average loss at step  98000 :  4.596578381776809
# Average loss at step  100000 :  4.715740369200707
# Nearest to into: through, from, on, with, spotter, under, aveiro, pontificia,
# Nearest to known: well, midland, used, such, branson, stitch, popeye, ranged,
# Nearest to but: however, and, while, although, cebus, dasyprocta, circ, or,
# Nearest to not: they, now, often, to, generally, microcebus, also, you,
# Nearest to than: or, but, much, cmf, dasyprocta, and, banks, ursus,
# Nearest to so: chymotrypsin, hence, tombaugh, cebus, amalthea, fruity, meridian, gd,
# Nearest to nine: eight, seven, six, five, zero, four, three, kapoor,
# Nearest to if: when, cebus, though, is, where, recitative, circ, microsite,
# Nearest to american: british, telling, tubing, frau, utraquists, circ, motorized, sedgwick,
# Nearest to such: these, well, many, known, conservatism, consisting, attackers, telangana,
# Nearest to years: laterally, polytheism, ursus, days, almonds, carrera, months, five,
# Nearest to four: five, three, seven, six, eight, two, zero, nine,
# Nearest to which: that, this, also, it, but, both, these, what,
# Nearest to five: four, seven, six, three, eight, nine, zero, two,
# Nearest to many: some, several, these, circ, all, other, various, aquilegia,
# Nearest to has: had, have, was, is, messenger, determining, having, pheasants,
